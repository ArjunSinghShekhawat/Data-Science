# %%
"""
Consider the below code to answer further questions:
import numpy as np
list_ = [ ‘1’ , ’2’ , ‘3’ , ‘4’ , ‘5’ ]
array_list = np.array(object = list_)
Q1. Is there any difference in the data type of variables list_ and array_list? If there is then write a code
to print the data types of both the variables.
Q2. Write a code to print the data type of each and every element of both the variables list_ and
arra_list.
Q3. Considering the following changes in the variable, array_list:
array_list = np.array(object = list_, dtype = int)
Will there be any difference in the data type of the elements present in both the variables, list_ and
arra_list? If so then print the data types of each and every element present in both the variables, list_
and arra_list.
Consider the below code to answer further questions:
import numpy as np
num_list = [ [ 1 , 2 , 3 ] , [ 4 , 5 , 6 ] ]
num_array = np.array(object = num_list)
Q4. Write a code to find the following characteristics of variable, num_array:
(i) shape
(ii) size
Q5. Write a code to create numpy array of 3*3 matrix containing zeros only, using a numpy array
creation function.
[Hint: The size of the array will be 9 and the shape will be (3,3).]
Q6. Create an identity matrix of shape (5,5) using numpy functions?
[Hint: An identity matrix is a matrix containing 1 diagonally and other elements will be 0.]
"""

# %% [markdown]
# Q1. Yes, there is a difference in the data type of variables `list_` and `array_list`. You can use the `dtype` attribute to check the data types of both variables. Here's the code to print the data types:
#
#
# import numpy as np
#
# list_ = ['1', '2', '3', '4', '5']
# array_list = np.array(list_)
#
# print("Data type of list_:", type(list_[0]))
# print("Data type of array_list:", array_list.dtype)
#
# Q2. To print the data type of each element in both `list_` and `array_list`, you can iterate through the elements and use the `type()` function. Here's the code:
#
#
# import numpy as np
#
# list_ = ['1', '2', '3', '4', '5']
# array_list = np.array(list_)
#
# for element in list_:
#     print("Data type of element in list_:", type(element))
#
# for element in array_list:
#     print("Data type of element in array_list:", type(element))
#
#
# Q3. When you change the data type of the elements in `array_list` to `int`, there will be a difference in the data type. You can print the data types of elements in both variables using the code below:
#
#
# import numpy as np
#
# list_ = ['1', '2', '3', '4', '5']
# array_list = np.array(list_, dtype=int)
#
# for element in list_:
#     print("Data type of element in list_:", type(element))
#
# for element in array_list:
#     print("Data type of element in array_list:", type(element))
#
#
# Q4. To find the shape and size of the `num_array` variable:
#
#
# import numpy as np
#
# num_list = [[1, 2, 3], [4, 5, 6]]
# num_array = np.array(num_list)
#
# print("Shape of num_array:", num_array.shape)
# print("Size of num_array:", num_array.size)
#
#
# Q5. To create a 3x3 numpy array with zeros:
#
# import numpy as np
#
# zero_array = np.zeros((3, 3))
#
#
# Q6. To create a 5x5 identity matrix using numpy:
#
#
# import numpy as np
#
# identity_matrix = np.eye(5)
#
#
# An identity matrix is a square matrix with ones along the main diagonal and zeros everywhere else. In this case, it's a 5x5 matrix with ones on the diagonal and zeros in all other positions.
